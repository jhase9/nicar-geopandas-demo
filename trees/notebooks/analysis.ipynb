# %% [markdown]
# # NICAR 2026 geopandas demo
#
# This notebook demonstrates a geospatial analysis of San Francisco trees, neighborhoods, and schools.
#
# **Data in the `data/` folder:**
# - `sf_trees.csv` — street trees in SF planted since 2020 (CSV)
# - `sf_neighborhoods.zip` — SF neighborhood boundaries (shapefile)
# - `sf_schools.geojson` — SF schools (geojson)
#
# **Let's take a look at our files!**

# %% [markdown]
# ## Importing libraries and loading the data

# %% [markdown]
# ##### Import libraries

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Let's load in our data!

# %% [markdown]
# Load in the neighborhoods shapefile with `gpd.read_file()`

# %%
# Out:
#                 nhood                                           geometry
# 0    Western Addition  POLYGON ((-122.42144 37.78557, -122.42136 37.7...
# 1  West of Twin Peaks  POLYGON ((-122.46104 37.75096, -122.46055 37.7...
# 2   Visitacion Valley  POLYGON ((-122.40385 37.71883, -122.40355 37.7...
# 3          Twin Peaks  POLYGON ((-122.44695 37.75655, -122.44595 37.7...
# 4     South of Market  POLYGON ((-122.40371 37.78404, -122.40271 37.7...

# %% [markdown]
# Load in the schools geojson with `gpd.read_file()`

# %%
# Out:
#   record_type            cds_code               district  \
# 0      School  38,684,780,119,958  San Francisco Unified
# 1      School  38,684,786,930,572  San Francisco Unified
# 2      School  38,684,786,040,695  San Francisco Unified
# 3      School  38,684,786,168,959  San Francisco Unified
# 4      School  38,684,786,172,357  San Francisco Unified
#
#                        school  status           open_date charter_yesno  \
# 0  Academy (The)- SF @McAteer  Active 2009-08-24 12:00:00         false
# 1       Adda Clevenger School  Active 1980-07-01 12:00:00         false
# 2            Alamo Elementary  Active 1980-07-01 12:00:00         false
# 3         Aloha Micro Academy  Active 2023-12-04 12:00:00         false
# 4  Alpha School San Francisco  Active 2025-08-25 12:00:00         false
#
#        educational_program_type                    entity_type low_grade  ...  \
# 0  Alternative School of Choice  Alternative Schools of Choice         9  ...
# 1                       No Data    Elementary School (Private)         K  ...
# 2                   Traditional    Elementary Schools (Public)         K  ...
# 3                       No Data         K-12 Schools (Private)         K  ...
# 4                       No Data    Elementary School (Private)         K  ...
#
#      street_city street_state  street_zip           phone  \
# 0  San Francisco           CA  94131-1616  (415) 695-5700
# 1  San Francisco           CA  94110-2927  (415) 824-2240
# 2  San Francisco           CA  94121-2009  (415) 750-8456
# 3  San Francisco           CA  94108-5628  (719) 877-3592
# 4  San Francisco           CA  94123-1710  (512) 595-0801
#
#                            point           analysis_neighborhood  \
# 0  POINT (-122.449984 37.745874)                       Glen Park
# 1   POINT (-122.424159 37.75368)                         Mission
# 2  POINT (-122.482191 37.783124)                  Outer Richmond
# 3   POINT (-122.40612 37.787767)  Financial District/South Beach
# 4   POINT (-122.433941 37.80457)                          Marina
#
#   supervisor_district          data_as_of      data_loaded_at  \
# 0                 8.0 2026-02-03 02:02:06 2026-02-06 02:16:51
# 1                 8.0 2026-02-03 02:02:06 2026-02-06 02:16:51
# 2                 1.0 2026-02-03 02:02:06 2026-02-06 02:16:51
# 3                 3.0 2026-02-03 02:02:06 2026-02-06 02:16:51
# 4                 2.0 2026-02-03 02:02:06 2026-02-06 02:16:51
#
#                       geometry
# 0  POINT (-122.44998 37.74587)
# 1  POINT (-122.42416 37.75368)
# 2  POINT (-122.48219 37.78312)
# 3  POINT (-122.40612 37.78777)
# 4  POINT (-122.43394 37.80457)
#
# [5 rows x 24 columns]

# %% [markdown]
# Load in the trees CSV with `pd.read_csv()`

# %% [markdown]
# Convert the CSV into a geo dataframe
# ```
# gpd.GeoDataFrame(yourDataFrameName,
#                 geometry=gpd.points_from_xy(lng_column, lat_column),
#                 crs='EPSG:4326')
#
# ```
#
# We're starting with a geographic CRS for now!

# %%
# Out:
#    TreeID    qLegalStatus    qSpecies        qAddress  SiteOrder  \
# 0  235418  DPW Maintained  Tree(s) ::    3466 21st St        2.0
# 1  261322         Private          ::  811 Duboce Ave        1.0
#
#                       qSiteInfo PlantType qCaretaker qCareAssistant  \
# 0  Sidewalk: Curb side : Cutout      Tree    Private            NaN
# 1  Sidewalk: Curb side : Cutout      Tree    Private            NaN
#
#                  PlantDate  DBH   PlotSize           PermitNotes  \
# 0  2020 Jan 02 12:00:00 AM  3.0  Width 3ft  Permit Number 784779
# 1  2020 Jan 02 12:00:00 AM  3.0        3x3                   NaN
#
#          XCoord        YCoord   Latitude   Longitude  \
# 0  6.005282e+06  2.103732e+06  37.756746 -122.424727
# 1           NaN           NaN        NaN         NaN
#
#                                    Location                     geometry
# 0  (37.75674627772118, -122.42472718600857)  POINT (-122.42473 37.75675)
# 1                                       NaN                  POINT EMPTY

# %% [markdown]
# Make sure everything has the same CRS with `.to_crs()`.

# %% [markdown]
# ## Visualizing the data
# Let's make a map with layers for neighborhoods, trees, and schools!

# %%
# Define our figure size and axes with `plt.subplots()`
fig, ax = plt.subplots(figsize=(10, 10))

# Plot our neighborhoods with `.plot()`

# Plot our trees with `.plot()`

# Plot our schools with `.plot()`

# Optional parameters for legend; layout        
ax.legend()
ax.axis('off')
plt.tight_layout()

# Show our map with `plt.show()`!
plt.show()

# %% [markdown]
# ## Question 1: Which neighborhoods have the most trees?

# %% [markdown]
# ### Merging neighborhoods data with trees data

# %% [markdown]
# Let's remind ourselves what our `neighborhoods` data looks like

# %%
# Out:
#                 nhood                                           geometry
# 0    Western Addition  POLYGON ((-122.42144 37.78557, -122.42136 37.7...
# 1  West of Twin Peaks  POLYGON ((-122.46104 37.75096, -122.46055 37.7...
# 2   Visitacion Valley  POLYGON ((-122.40385 37.71883, -122.40355 37.7...
# 3          Twin Peaks  POLYGON ((-122.44695 37.75655, -122.44595 37.7...
# 4     South of Market  POLYGON ((-122.40371 37.78404, -122.40271 37.7...

# %% [markdown]
# And then join our neighborhoods data with our trees data using `gpd.sjoin()` with `within`

# %% [markdown]
# Check to make sure all our data is in a neighborhood

# %%
# Out:
# True

# %% [markdown]
# #### Getting recent trees by neighborhood

# %% [markdown]
# Use `groupby()` to see counts by neighborhood

# %%
# Out:
#                     nhood  count
# 0   Bayview Hunters Point    330
# 17                Mission    316
# 33        Sunset/Parkside    259
# 24         Outer Richmond    253
# 37     West of Twin Peaks    178

# %% [markdown]
# Make a new column for percentages if desired

# %%
# Out:
#                     nhood  count  pct
# 0   Bayview Hunters Point    330  9.7
# 17                Mission    316  9.3
# 33        Sunset/Parkside    259  7.6
# 24         Outer Richmond    253  7.4
# 37     West of Twin Peaks    178  5.2

# %% [markdown]
# #### Let's map it!

# %% [markdown]
# Merge neighborhood geometries back in with `merge()`

# %%
# Out:
#                 nhood                                           geometry  \
# 0    Western Addition  POLYGON ((-122.42144 37.78557, -122.42136 37.7...
# 1  West of Twin Peaks  POLYGON ((-122.46104 37.75096, -122.46055 37.7...
# 2   Visitacion Valley  POLYGON ((-122.40385 37.71883, -122.40355 37.7...
# 3          Twin Peaks  POLYGON ((-122.44695 37.75655, -122.44595 37.7...
# 4     South of Market  POLYGON ((-122.40371 37.78404, -122.40271 37.7...
#
#    count  pct
# 0   89.0  2.6
# 1  178.0  5.2
# 2   26.0  0.8
# 3   14.0  0.4
# 4  102.0  3.0

# %% [markdown]
# Create a choropleth map with `plot()`

# %%
# set figure size
fig, ax = plt.subplots(figsize=(8, 8))

# set up map: specify column, color scheme, etc.


# show map
plt.show()

# %% [markdown]
# ## Question 2: What's the most common type of tree being planted in each neighborhood?

# %% [markdown]
# What are the most common types overall? Let's find out with `groupby()`

# %%
# Out:
#                                               qSpecies  count
# 101              Lophostemon confertus :: Brisbane Box    324
# 192              Tristaniopsis laurina :: Swamp Myrtle    233
# 111          Magnolia grandiflora :: Southern Magnolia    169
# 190                                         Tree(s) ::    138
# 149     Platanus x hispanica :: Sycamore: London Plane    130
# ..                                                 ...    ...
# 19   Aesculus x carnea 'O'Neill' :: O'Neill Red Hor...      1
# 146           Platanus racemosa :: California Sycamore      1
# 42                Celtis sinensis :: Chinese Hackberry      1
# 90         Koelreuteria paniculata :: Golden Rain Tree      1
# 33                     Brahea edulis :: Guadalupe Palm      1
#
# [204 rows x 2 columns]

# %% [markdown]
# Let's break it down by neighborhood — first, `groupby()` neighborhood and request type

# %% [markdown]
# Then sort and use `drop_duplicates()` to get the most common tree in each neighborhood

# %% [markdown]
# Take a look at the data

# %%
# Out:
#                                nhood  \
# 1001              West of Twin Peaks
# 441                          Mission
# 1014                Western Addition
# 42             Bayview Hunters Point
# 358        Cupressocyparis leylandii :: Leyland Cypress      5   16.666667
# 948   Ceanothus 'Ray Hartman' :: California Lilac 'R...      5   35.714286
# 958               Lophostemon confertus :: Brisbane Box      4   15.384615
# 855          Arbutus 'Marina' :: Hybrid Strawberry Tree      3   20.000000
# 215     Prunus subhirtella 'autumnalis' :: Higan Cherry      3   11.538462
# 354                                          Tree(s) ::      2  100.000000
# 806               Tristaniopsis laurina :: Swamp Myrtle      1  100.000000
# 351               Lophostemon confertus :: Brisbane Box      1   50.000000
# 353                                          Tree(s) ::      1  100.000000

# %% [markdown]
# ##### Let's map it!

# %% [markdown]
# Merge the data with the geometries with `.merge()`

# %% [markdown]
# Visualize the data using `plot()`

# %%
# set figure size
fig, ax = plt.subplots(figsize=(20, 20))

# set up map: specify column, color scheme, etc.


# show map
plt.show()

# %% [markdown]
# ## Question 3: How many trees fall within 1,000 feet of a public school?

# %% [markdown]
# ##### Filter our schools to public schools using the `public_yesno` column

# %% [markdown]
# ##### Switch our CRS to _geometry_ instead of _geography_.
# **Geographic** Coordinate Reference Systems use degrees (lat/long) to locate things on a sphere.
# **Projected** Coordinate Reference Systems  use a 2D plane in meters and feet — helpful to measure distances!

# %% [markdown]
# We're going to use a local SF projection; adapt to your location as needed.

# %%
crs_feet = 'EPSG:7132'

# %% [markdown]
# Update the crs for schools and trees data

# %% [markdown]
# ##### Create a buffer around the schools and find trees within it

# %% [markdown]
# Add a column with a buffer of 1000 ft around each school using `buffer()`

# %% [markdown]
# Create a new dataframe using `sjoin()` to find trees within the school buffer

# %% [markdown]
# Since one point might fall into more than one buffer area, let's drop duplicates (on `TreeID`).

# %% [markdown]
# Check what share of trees is near a school

# %%
# Out:
# 57.643758765778394

# %% [markdown]
# ##### Visualize the data

# %%
# Define our figure size and axes with `plt.subplots()`
fig, ax = plt.subplots(figsize=(10, 10))

# Plot our trees with `.plot()`

# Plot our schools with `.plot()` - don't forget to change the CRS! 

# Optional parameters for legend; layout        
ax.legend()
ax.axis('off')
plt.tight_layout()

# Show our map with `plt.show()`!
plt.show()

# %% [markdown]
# ## Question 4: Which public school has the most trees nearby?

# %% [markdown]
# Use `groupby` to count trees by school

# %% [markdown]
# Sort and look at the data

# %%
# Out:
#                                       school  count
# 0                          Bryant Elementary     71
# 1                                Balboa High     67
# 2                    Harte (Bret) Elementary     62
# 3    Burton (Phillip and Sala) Academic High     59
# 4                Peabody (George) Elementary     51
# ..                                       ...    ...
# 108            Thomas Edison Charter Academy      1
# 109                      Miraloma Elementary      1
# 110                       Rooftop Elementary      1
# 111      San Francisco Community Alternative      1
# 112               Academy (The)- SF @McAteer      1
#
# [113 rows x 2 columns]

# %% [markdown]
# At the end of the class, please shut down your terminal with `Ctrl + C`.
